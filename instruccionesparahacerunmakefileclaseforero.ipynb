# %% [raw]
# make por si solo me busca el makefile .... COMPARA FECHAS ENTRE ARCHIVOS
#
# make -f makefile01.o
#
# como está escrito un archivo de esos?
#
# requirement ... cosa en python
# target... la grafica
#
# si requirement ha sido modificado más nuevo que el target...
#
# target1.dat:    requirement1.dat
#     echo "compared to target1.dat, the file requirement1.dat has benn recently changed"
#     touch target 1.dat
#
# touch si no existe lo crea... y si existe le cambia la fecha de modificación
#
# make -f makefile.0
#
#
# _____
#
# NIVEL 2
#
# columna_3.dat:   data_test.csv
#
#     awk -F "\"*,\"'{print $3}' data_test.csv > columna_3.dat
#
# _____
# NIVEL 3 :O
#
# columna_3.dat:   data_test.csv
#     awk -F "\"*,\"'{print $3}' data_test.csv > columna_3.dat
#
# columna_4.dat:   data_test.csv
#     awk -F "\"*,\"'{print $4}' data_test.csv > columna_3.dat
#
# solo hizo 3, no 4
# make solo ejecuta la primera
# toca forzarlo hmmmm
#
#
# make -f makefile columna_4.dat que esta de 2 hace el 4
#
# ____
# NIVEL 4
#
# all: columna_4.dat columna_3.dat
#
# columna_3.dat:   data_test.csv
#     awk -F "\"*,\"'{print $3}' data_test.csv > columna_3.dat
#
# columna_4.dat:   data_test.csv
#     awk -F "\"*,\"'{print $4}' data_test.csv > columna_3.dat
#
# hacer los 2 :D
# No importa el orden!! :D :D
# ______
# NIVEL 5
# clean:
#     rm -f columna_4.dat calomna_3.dat
#
# siempre me va a hacer porque no tiene requirement
#
# puedo mezclar clean y all
#
# ______
# Nivel 6
#
# a.out:  main.c geometry.c io.c .. tres archivos que tienen todo el código si cambio uno, tiene que actualizarme.
#
#     cc main.c geometry.c io.c -lm (funcione la libreria de math.h porque use por pow la potencia)
# va a crear el archivo a.out  y va los va a hacer
#
# si actalizo el main que es el requirement entonces me va a compilar
#
# Compilar por separado cc -c, para unir se cojen los .o  (intermedio--- objeto)
# _____
# Nivel 7
#
# all: a.out
#
# a.out: main.o geometry.o io.o
#     cc main.o geomtry.o io.o -lm
#
# main.o: main.c
#
#     cc -c main.c
#
# io.o: io.c
#
#     cc -c main.c
#
# geometry.o: geomtry.c
#
#     cc -c main.c
#
# git fersh (baja el nuevo)
# git mersh (une trabajos)
